# %%
import folium as f
from folium_vectortilelayer import VectorTileLayer
from ellipsis-folium import addEllipsisRasterLayer

map = f.Map()


pathId = '93e1c322-f21e-4395-9566-51abf473d2b9'

ED_layer = addEllipsisRasterLayer(pathId)

print(ED_layer)

ED_layer.add_to(map)

map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_29656/93523495.py in <module>
#       1 import folium as f
#       2 from folium_vectortilelayer import VectorTileLayer
# ----> 3 from app import addEllipsisRasterLayer
#       4
#       5 map = f.Map()
#
# ModuleNotFoundError: No module named 'app'

# %%
import folium as f
from folium_vectortilelayer import VectorTileLayer
from app import addEllipsisVectorLayer

map = f.Map()


pathId = '8a11c27b-74c3-4570-bcd0-64829f7cd311'
styleId = '873b4946-706e-49f8-a9c2-fbe15232948a'
#styleId = '2c50bc73-105a-47f5-abd3-70a7c29504aa'

ED_layer = addEllipsisVectorLayer(pathId, style=styleId)

print(ED_layer)

map.add_child(ED_layer)

map
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# <folium_vectortilelayer.vectortilelayer.VectorTileLayer object at 0x7f87abd861a0>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9c515f31d2111db6e1d7722b70d99ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-vector-tile-layer@latest/dist/VectorTileLayer.umd.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9c515f31d2111db6e1d7722b70d99ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9c515f31d2111db6e1d7722b70d99ad = L.map(
#                 &quot;map_a9c515f31d2111db6e1d7722b70d99ad&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34da350a134619d674a2b6a7fd56c06f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9c515f31d2111db6e1d7722b70d99ad);
#
#     var vector_tile_layer_7b97ca1122787616bbfc3d7b282fd308 = VectorTileLayer.default(
#                 &quot;https://api.ellipsis-drive.com/v3/ogc/mvt/8a11c27b-74c3-4570-bcd0-64829f7cd311/{z}/{x}/{y}?timestampId=80da827e-a5cf-4972-a24a-aa9a40813876&quot;,
#
#                 {
#       &quot;layers&quot;: [&quot;layer&quot;],
#     &quot;minZoom&quot;: 0,
#     &quot;maxZoom&quot;: 5,
#     &quot;minDetailZoom&quot;: 0,
#     &quot;maxDetailZoom&quot;: 5,
#       &quot;vectorTileLayerStyles&quot;: {
#         &quot;layer&quot;: function(f){if(f.AREA==0){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#c53edf&quot;,&quot;color&quot;:&quot;#c53edf&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==1){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#44cb63&quot;,&quot;color&quot;:&quot;#44cb63&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==2){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#1cf44d&quot;,&quot;color&quot;:&quot;#1cf44d&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==3){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#79d67f&quot;,&quot;color&quot;:&quot;#79d67f&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==5){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#82c9b0&quot;,&quot;color&quot;:&quot;#82c9b0&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==10){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#10aefd&quot;,&quot;color&quot;:&quot;#10aefd&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==14){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#36b23a&quot;,&quot;color&quot;:&quot;#36b23a&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==15){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#6aff78&quot;,&quot;color&quot;:&quot;#6aff78&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==16){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#b91983&quot;,&quot;color&quot;:&quot;#b91983&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==20){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#4d6ac7&quot;,&quot;color&quot;:&quot;#4d6ac7&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==24){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#c40650&quot;,&quot;color&quot;:&quot;#c40650&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==26){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#67cf31&quot;,&quot;color&quot;:&quot;#67cf31&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==30){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#94118e&quot;,&quot;color&quot;:&quot;#94118e&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==32){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#27a3d3&quot;,&quot;color&quot;:&quot;#27a3d3&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==34){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#b6d227&quot;,&quot;color&quot;:&quot;#b6d227&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==35){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#abb597&quot;,&quot;color&quot;:&quot;#abb597&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==36){return({&quot;fill&quot;:true,&quot;weight&quot;:5,&quot;fillColor&quot;:&quot;#a84b6f&quot;,&quot;color&quot;:&quot;#a84b6f&quot;,&quot;fillOpacity&quot;:0.5,&quot;opacity&quot;:1});}if(f.AREA==39){return({&quot;fill&quot;:true

# %%
exit()
